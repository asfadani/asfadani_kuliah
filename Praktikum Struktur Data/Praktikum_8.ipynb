# %% [markdown]
# **1. Representasi Graf dengan Adjacency List**

# %%
# Membuat graf dengan adjacency list
graph = {
    'A' : ['B', 'C'],
    'B' : ['A', 'D', 'E'],
    'C' : ['A', 'F'],
    'D' : ['B'],
    'E' : ['B', 'F'],
    'F' : ['C', 'e']
}

# Menampilkan graf
def  print_graph(graf):
    for node in graf:
        print(f"{node} -> {graf[node]}")

# %%
print_graph(graph)
# Out:
# A -> ['B', 'C']
# B -> ['A', 'D', 'E']
# C -> ['A', 'F']
# D -> ['B']
# E -> ['B', 'F']
# F -> ['C', 'e']

# %% [markdown]
# **2. Traversal Graf  menggunakan  BFS**

# %%
from collections import deque

def bfs(graph, start):
    visited = set()
    queue = deque([start])

    while queue:
        vertex = queue.popleft()
        if vertex not in  visited:
            print(vertex, end=" ")
            visited.add(vertex)
            queue.extend([neighbor for neighbor in graph[vertex] if neighbor not in visited])

# %%
bfs(graph, "A")
# Out:
# A B C D E F e
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 bfs(graph, "A")
#
# Cell In[3], line 12, in bfs(graph, start)
#      10 print(vertex, end=" ")
#      11 visited.add(vertex)
# ---> 12 queue.extend([neighbor for neighbor in graph[vertex] if neighbor not in visited])
#
# KeyError: 'e'

# %% [markdown]
# **3. Traversal Graf menggunakan DFS**

# %%
def dfs(graph, start, visited=None):
    if visited is None :
        visited = set()

    if start not in visited:
        print(start, end=" ")
        visited.add(start)
        for neighbor in graph[start]:
            dfs(graph, neighbor, visited)

# %%
dfs(graph, "A")
# Out:
# A B D E F C e
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dfs(graph, "A")
#
# Cell In[5], line 9, in dfs(graph, start, visited)
#       7 visited.add(start)
#       8 for neighbor in graph[start]:
# ----> 9     dfs(graph, neighbor, visited)
#
# Cell In[5], line 9, in dfs(graph, start, visited)
#       7 visited.add(start)
#       8 for neighbor in graph[start]:
# ----> 9     dfs(graph, neighbor, visited)
#
#     [... skipping similar frames: dfs at line 9 (1 times)]
#
# Cell In[5], line 9, in dfs(graph, start, visited)
#       7 visited.add(start)
#       8 for neighbor in graph[start]:
# ----> 9     dfs(graph, neighbor, visited)
#
# Cell In[5], line 8, in dfs(graph, start, visited)
#       6 print(start, end=" ")
#       7 visited.add(start)
# ----> 8 for neighbor in graph[start]:
#       9     dfs(graph, neighbor, visited)
#
# KeyError: 'e'

# %%
def count_neighbor(graph):
    result = {}
    for node in graph:
        pass
    return result
